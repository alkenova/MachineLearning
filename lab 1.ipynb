# %%
import pandas as pd
import numpy as np

# %%
adult = pd.read_csv('F:/Study/methodpro/ml/labs/adult/adult.data.csv')

# %%
adult.columns=['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_loss', 'capital_gain', 'hours_per_week', 'native_status', 'salary']

# %%
adult.tail()
# Out:
#        age     workclass  fnlwgt   education  education_num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital_status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital_loss  capital_gain  hours_per_week  native_status salary
# 32556             0             0              38  United-States  <=50K
# ...

# %%
adult.sex.value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
adult[adult['sex'] == 'Female'].age.mean()
# Out:
# 36.85823043357163

# %%
(adult['native_status'] == 'Germany').sum() / adult.shape[0]
# Out:
# 0.004207487485028101

# %%
adult[adult['salary'] == '>50K']['age'].mean() , \
adult[adult['salary'] == '>50K']['age'].std() , \
adult[adult['salary'] == '<=50K']['age'].mean() , \
adult[adult['salary'] == '<=50K']['age'].std()
# Out:
# (44.24984058155847, 10.519027719851826, 36.78373786407767, 14.02008849082488)

# %%
adult[adult['salary'] == '>50K']['education'].unique()
# Out:
# array(['HS-grad', 'Masters', 'Bachelors', 'Some-college', 'Assoc-voc',
#        'Doctorate', 'Prof-school', 'Assoc-acdm', '7th-8th', '12th',
#        '10th', '11th', '9th', '5th-6th', '1st-4th'], dtype=object)

# %%
adult['hours_per_week'].max()
# Out:
# 99

# %%
adult[adult['hours_per_week']==adult['hours_per_week'].max()].shape[0]
# Out:
# 85

# %%
adult.groupby(['race','sex'])['age'].describe()
# Out:
#                              count       mean        std   min   25%   50%  \
# race               sex
# Amer-Indian-Eskimo Female    119.0  37.117647  13.114991  17.0  27.0  36.0
#                    Male      192.0  37.208333  12.049563  17.0  28.0  35.0
# Asian-Pac-Islander Female    346.0  35.089595  12.300845  17.0  25.0  33.0
#                    Male      693.0  39.073593  12.883944  18.0  29.0  37.0
# Black              Female   1555.0  37.854019  12.637197  17.0  28.0  37.0
#                    Male     1569.0  37.682600  12.882612  17.0  27.0  36.0
# Other              Female    109.0  31.678899  11.631599  17.0  23.0  29.0
#                    Male      162.0  34.654321  11.355531  17.0  26.0  32.0
# White              Female   8642.0  36.811618  14.329093  17.0  25.0  35.0
#                    Male    19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# race               sex
# Amer-Indian-Eskimo Female  46.00  80.0
# ...

# %%
pd.crosstab(adult['sex'], adult['race'], values=adult['age'], aggfunc=np.max).T
# Out:
# sex                 Female  Male
# race
# Amer-Indian-Eskimo      80    82
# Asian-Pac-Islander      75    90
# Black                   90    90
# Other                   74    77
# White                   90    90

# %%
adult[adult['marital_status'].str.contains("Married") & (adult['salary'] == '>50K') & (adult['sex'] == 'Male')].shape[0] / adult[adult['marital_status'].str.contains("Married") & (adult['sex'] == 'Male')].shape[0]
# Out:
# 0.4405139945351156

# %%
adult[~adult['marital_status'].str.contains("Married") & (adult['salary'] == '>50K') & (adult['sex'] == 'Male')].shape[0] / adult[~adult['marital_status'].str.contains("Married") & (adult['sex'] == 'Male')].shape[0]
# Out:
# 0.08449509031397745

# %%
pd.crosstab(adult['salary'], adult['native_status'], values=adult['hours_per_week'], aggfunc=np.mean).T
# Out:
# salary                          <=50K       >50K
# native_status
# ?                           40.164760  45.547945
# Cambodia                    41.416667  40.000000
# Canada                      37.914634  45.641026
# China                       37.381818  38.900000
# Columbia                    38.684211  50.000000
# Cuba                        37.985714  42.440000
# Dominican-Republic          42.338235  47.000000
# Ecuador                     38.041667  48.750000
# El-Salvador                 36.030928  45.000000
# England                     40.483333  44.533333
# France                      41.058824  50.750000
# Germany                     39.139785  44.977273
# Greece                      41.809524  50.625000
# Guatemala                   39.360656  36.666667
# Haiti                       36.325000  42.750000
# Holand-Netherlands          40.000000        NaN
# Honduras                    34.333333  60.000000
# Hong                        39.142857  45.000000
# ...
